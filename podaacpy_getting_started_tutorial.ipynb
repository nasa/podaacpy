# %%
##################
# Imports        #
##################
# import the podaac package
import podaac.podaac as podaac
# import the podaac_utils package
import podaac.podaac_utils as utils
# import the mcc package
import podaac.mcc as mcc

#######################
# Class instantiation #
#######################
# then create an instance of the Podaac class
p = podaac.Podaac()
# then create an instance of the PodaacUtils class
u = utils.PodaacUtils()
# then create an instance of the MCC class
m = mcc.MCC()

# %%
###########################################
# Lets look at some convenience functions #
###########################################

print(u.list_available_granule_search_level2_datasetIds())
# Out:
# ['PODAAC-AKASA-XOGD1', 'PODAAC-GHAM2-2PR72', 'PODAAC-ASOP2-25X01', 'PODAAC-ASOP2-12C01', 'PODAAC-ASOP2-25B01', 'PODAAC-ASOP2-COB01', 'PODAAC-GHAMT-2PE01', 'PODAAC-GHMDA-2PJ01', 'PODAAC-GHMDT-2PJ01', 'PODAAC-GH18G-2PN01', 'PODAAC-GH19G-2PN01', 'PODAAC-GHMTG-2PN01', 'PODAAC-OSCT2-L2BV2', 'PODAAC-J2ODR-GPS00', 'PODAAC-QSX12-L2B01', 'PODAAC-GHAMS-2PR01', 'PODAAC-GHVRS-2PN02']

# %%
print(u.list_available_granule_search_level2_datasetShortNames())
# Out:
# ['ALTIKA_SARAL_L2_OST_XOGDR', 'AMSR2-REMSS-L2P-v7.2', 'ASCATA-L2-25km', 'ASCATA-L2-Coastal', 'ASCATB-L2-25km', 'ASCATB-L2-Coastal', 'EUR-L2P-AVHRR_METOP_A', 'JPL-L2P-MODIS_A', 'JPL-L2P-MODIS_T', 'NAVO-L2P-AVHRR18_G', 'NAVO-L2P-AVHRR19_G', 'NAVO-L2P-AVHRRMTA_G', 'OS2_OSCAT_LEVEL_2B_OWV_COMP_12_V2', 'OSTM_L2_OST_OGDR_GPS', 'QSCAT_LEVEL_2B_OWV_COMP_12', 'REMSS-L2P-AMSRE', 'VIIRS_NPP-NAVO-L2P-v1.0']

# %%
print(u.list_available_granule_search_datasetIds())
# Out:
# ['PODAAC-QSX25-L2B02', 'PODAAC-NAVOC-2LAC1', 'PODAAC-GHSEV-3CO01', 'PODAAC-AQR40-3WRAS', 'PODAAC-REY3B-ERMOA', 'PODAAC-AQR40-3R1DS', 'PODAAC-AQR40-3D1CS', 'PODAAC-GEOS3-AGDRA', 'PODAAC-SMMRN-2WAF0', 'PODAAC-AQR40-3S3AS', 'PODAAC-AQR40-3RAAS', 'PODAAC-AQR40-3R3CS', 'PODAAC-MODST-8D9D4', 'PODAAC-GHRAN-4FJ01', 'PODAAC-SPUR1-UCTD0', 'PODAAC-QSSIA-BYU01', 'PODAAC-GHNMT-3PE01', 'PODAAC-AQR40-3SUDS', 'PODAAC-QSSWS-CMIP1', 'PODAAC-MODCA-3M4R4', 'PODAAC-QSXXX-L3002', 'PODAAC-TEOCN-0AJ05', 'PODAAC-GH18L-2PS01', 'PODAAC-RSX12-L2B11', 'PODAAC-RSX12-L2B12', 'PODAAC-TEOCN-0T005', 'PODAAC-GRAOD-1BG05', 'PODAAC-TEGLD-MAN01', 'PODAAC-GOES3-1HOUR', 'PODAAC-TPMGD-XOVRB', 'PODAAC-MODSA-MO9D4', 'PODAAC-AQR40-3S1CS', 'PODAAC-TEMSC-2CL05', 'PODAAC-TELND-AN005', 'NODCNA-J2GPS-NC00D', 'PODAAC-ERS13-IMWF0', 'PODAAC-J1SHA-NETCC', 'PODAAC-ALTTS-TJ123', 'PODAAC-GHAMS-2GR01', 'PODAAC-GHAMS-2GR07', 'PODAAC-ASOP2-12X01', 'PODAAC-QSBYU-ANBLT', 'PODAAC-SEABY-ARBIM', 'PODAAC-J1GDR-BIN0C', 'PODAAC-ERS2X-IMWF0', 'PODAAC
# ...

# %%
print(u.list_available_granule_search_datasetShortNames())
# Out:
# ['QSCAT_OSUCOAS_L3_OW_USWestCoast', 'GRACE_GAB_L2_GRAV_JPL_RL05_1', 'EUR-L3P-GLOB_AVHRR_METOP_A', 'AQUARIUS_L3_ANCILLARY_SST_SMI_28DAY-RUNNINGMEAN_V4', 'TMI-REMSS-L2P-v4', 'AVHRR_PATHFINDER_L3_SST_7DAY_NIGHTTIME_V51', 'MODIS_AQUA_L3_SST_THERMAL_ANNUAL_4KM_NIGHTTIME_V2014.0', 'TELLUS_OCEANEOF_GIF_JPL_RL05', 'AQUARIUS_L3_ANCILLARY_SST_SMID_MONTHLY-CLIMATOLOGY_V4', 'GOES15-OSPO-L2P-v1.0', 'AQUARIUS_L3_SSS_SMIA_ANNUAL_V4', 'SPURS1_WAVEGLIDER', 'GOES_L3_SST_6km_NRT_SST_24HOUR', 'AQUARIUS_L3_ANCILLARY_SST_SMID_ANNUAL_V4', 'NSCAT_W25_RMGDR_V2', 'AVHRR_PATHFINDER_L3_SST_8DAY_NIGHTTIME_V5', 'AVHRR_PATHFINDER_L3_SST_MONTHLY_DAYTIME_V51', 'AQUARIUS_L3_ANCILLARY_SST_SMID_SEASONAL-CLIMATOLOGY_V4', 'QSCAT_BYU_L3_OW_SIGMA0_ARCTIC_POLAR-STEREOGRAPHIC_BROWSE_IMAGES_LTOD', 'QSCAT_LEVEL_2B_V2', 'MODIS_AQUA_L3_SST_MID-IR_ANNUAL_4KM_NIGHTTIME_V2014.0', 'TOPEX_ALTSDR', 'CCMP_MEASURES_ATLAS_L3_OW_L2_5_SSMI_F10_WIND_VECTORS_FLK', 'TELLUS_OCEAN_TXT_JPL_RL05', 'MODIS_TERRA_L3_SST_MID-IR_MONTHLY_4KM_NIGHTTIME_
# ...

# %%
print(u.list_available_image_granule_datasetIds())
# Out:
# ['PODAAC-AKASA-XOGD1', 'PODAAC-GHAM2-2PR72', 'PODAAC-ASOP2-25X01', 'PODAAC-ASOP2-12C01', 'PODAAC-ASOP2-25B01', 'PODAAC-ASOP2-COB01', 'PODAAC-GHAMT-2PE01', 'PODAAC-GHMDA-2PJ01', 'PODAAC-GHMDT-2PJ01', 'PODAAC-GH18G-2PN01', 'PODAAC-GH19G-2PN01', 'PODAAC-GHMTG-2PN01', 'PODAAC-OSCT2-L2BV2', 'PODAAC-J2ODR-GPS00', 'PODAAC-QSX12-L2B01', 'PODAAC-GHAMS-2PR01', 'PODAAC-GHVRS-2PN02']

# %%
print(u.list_available_image_granule_datasetShortNames())
# Out:
# ['ALTIKA_SARAL_L2_OST_XOGDR', 'AMSR2-REMSS-L2P-v7.2', 'ASCATA-L2-25km', 'ASCATA-L2-Coastal', 'ASCATB-L2-25km', 'ASCATB-L2-Coastal', 'EUR-L2P-AVHRR_METOP_A', 'JPL-L2P-MODIS_A', 'JPL-L2P-MODIS_T', 'NAVO-L2P-AVHRR18_G', 'NAVO-L2P-AVHRR19_G', 'NAVO-L2P-AVHRRMTA_G', 'OS2_OSCAT_LEVEL_2B_OWV_COMP_12_V2', 'OSTM_L2_OST_OGDR_GPS', 'QSCAT_LEVEL_2B_OWV_COMP_12', 'REMSS-L2P-AMSRE', 'VIIRS_NPP-NAVO-L2P-v1.0']

# %%
print(u.list_available_extract_granule_datasetIds())
# Out:
# ['PODAAC-AKASA-XOGD1', 'PODAAC-GHAM2-2PR72', 'PODAAC-ASOP2-25X01', 'PODAAC-ASOP2-12C01', 'PODAAC-ASOP2-25B01', 'PODAAC-ASOP2-COB01', 'PODAAC-GHAMT-2PE01', 'PODAAC-GHMDA-2PJ01', 'PODAAC-GHMDT-2PJ01', 'PODAAC-GH18G-2PN01', 'PODAAC-GH19G-2PN01', 'PODAAC-GHMTG-2PN01', 'PODAAC-OSCT2-L2BV2', 'PODAAC-J2ODR-GPS00', 'PODAAC-QSX12-L2B01', 'PODAAC-GHAMS-2PR01', 'PODAAC-GHVRS-2PN02']

# %%
print(u.list_available_extract_granule_datasetShortNames())
# Out:
# ['ALTIKA_SARAL_L2_OST_XOGDR', 'AMSR2-REMSS-L2P-v7.2', 'ASCATA-L2-25km', 'ASCATA-L2-Coastal', 'ASCATB-L2-25km', 'ASCATB-L2-Coastal', 'EUR-L2P-AVHRR_METOP_A', 'JPL-L2P-MODIS_A', 'JPL-L2P-MODIS_T', 'NAVO-L2P-AVHRR18_G', 'NAVO-L2P-AVHRR19_G', 'NAVO-L2P-AVHRRMTA_G', 'OS2_OSCAT_LEVEL_2B_OWV_COMP_12_V2', 'OSTM_L2_OST_OGDR_GPS', 'QSCAT_LEVEL_2B_OWV_COMP_12', 'REMSS-L2P-AMSRE', 'VIIRS_NPP-NAVO-L2P-v1.0']

# %%
# Now lets take a look at using the results from above to interact with the Podaac Webservices

#######################
# Podaac Web Services #
#######################

# First lets Retrieving Dataset Metadata
print(p.load_dataset_md(datasetId='PODAAC-GHMG2-2PO01'))
# Out:
# <?xml version="1.0" ?>
# <gmd:DS_Series xmlns:gco="http://www.isotc211.org/2005/gco" xmlns:gmd="http://www.isotc211.org/2005/gmd" xmlns:gmi="http://www.isotc211.org/2005/gmi" xmlns:gml="http://www.opengis.net/gml/3.2" xmlns:gmx="http://www.isotc211.org/2005/gmx" xmlns:gsr="http://www.isotc211.org/2005/gsr" xmlns:gss="http://www.isotc211.org/2005/gss" xmlns:gts="http://www.isotc211.org/2005/gts" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.isotc211.org/2005/gmd https://cdn.earthdata.nasa.gov/iso/schema/1.0/ISO19115-2_EOS.xsd">
# 	<gmd:composedOf gco:nilReason="inapplicable"/>
# 	<gmd:seriesMetadata>
# 		<gmi:MI_Metadata id="OSDPD-L2P-MSG02">
# 			<gmd:fileIdentifier>
# 				<gco:CharacterString>
# 					OSDPD-L2P-MSG02
# 				</gco:CharacterString>
# 			</gmd:fileIdentifier>
# 			<gmd:language>
# 				<gco:CharacterString>
# 					eng
# 				</gco:CharacterString>
# 			</gmd:language>
# 			<gmd:characterSet>
# ...

# %%
# Now Retrieving Granule Metadata
print(p.load_granule_md(datasetId='PODAAC-GHMG2-2PO01', granuleName='20120912-MSG02-OSDPD-L2P-MSG02_0200Z-v01.nc'))
# Out:
# <?xml version="1.0" ?>
# <gmd:DS_Series xmlns:gco="http://www.isotc211.org/2005/gco" xmlns:gmd="http://www.isotc211.org/2005/gmd" xmlns:gmi="http://www.isotc211.org/2005/gmi" xmlns:gml="http://www.opengis.net/gml/3.2" xmlns:gmx="http://www.isotc211.org/2005/gmx" xmlns:gsr="http://www.isotc211.org/2005/gsr" xmlns:gss="http://www.isotc211.org/2005/gss" xmlns:gts="http://www.isotc211.org/2005/gts" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.isotc211.org/2005/gmd https://cdn.earthdata.nasa.gov/iso/schema/1.0/ISO19115-2_EOS.xsd">
# 	<gmd:composedOf>
# 		<gmd:DS_DataSet>
# 			<gmd:has>
# 				<gmi:MI_Metadata>
# 					<gmd:fileIdentifier>
# 						<gco:CharacterString>
# 							20120912-MSG02-OSDPD-L2P-MSG02_0200Z-v01.nc
# 						</gco:CharacterString>
# 					</gmd:fileIdentifier>
# 					<gmd:contact xlink:href="#seriesMetadataContact"/>
# 					<gmd:dateStamp>
# 						<gco:DateTime>
# ...

# %%
# Additionally, we can search metadata for list of granules archived within the last 24 hours in Datacasting format.
print(p.load_last24hours_datacasting_granule_md(datasetId='PODAAC-GHMG2-2PO01'))
# Out:
# <rss xmlns:datacasting="http://datacasting.jpl.nasa.gov/datacasting" version="2.0">
#    <channel>
#       <title>GHRSST Level 2P Atlantic Regional Skin Sea Surface Temperature from the Spinning Enhanced Visible and InfraRed Imager (SEVIRI) on the Meteosat Second Generation (MSG-2) satellite</title>
#       <link>http://podaac.jpl.nasa.gov/dataset/OSDPD-L2P-MSG02</link>
# ...

# %%
# Lets try Searching for Datasets
print(p.search_dataset(keyword='modis'))
# Out:
# <?xml version="1.0" ?>
# <feed xmlns="http://www.w3.org/2005/Atom" xmlns:dc="http://purl.org/dc/terms/" xmlns:georss="http://www.georss.org/georss" xmlns:gml="http://www.opengis.net/gml" xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/" xmlns:podaac="http://podaac.jpl.nasa.gov/opensearch/" xmlns:time="http://a9.com/-/opensearch/extensions/time/1.0/">
# 	<title>
# 		PO.DAAC Dataset Search Results
# 	</title>
# 	<updated>
# 		2016-07-14T09:40:27.664525Z
# 	</updated>
# 	<id>
# 		tag:podaac.jpl.nasa.gov,2016-07-14
# 	</id>
# 	<author>
# 		<name>
# 			PO.DAAC Dataset Search Service
# 		</name>
# 	</author>
# 	<link href="http://podaac.jpl.nasa.gov/ws/search/podaac-granule-osd.xml" rel="search" type="application/opensearchdescription+xml"/>
# 	<link href="http://podaac.jpl.nasa.gov/ws/search/dataset?startIndex=0&amp;itemsPerPage=7&amp;keyword=modis&amp;format=atom" rel="self" type="application/atom+xml"/>
# ...

# %%
# Now Searching for Granules
print(p.search_granule(datasetId='PODAAC-ASOP2-25X01',shortName='ASCATA-L2-25km',bbox='0,0,180,90',startTime='2013-01-01T01:30:00Z',endTime='2014-01-01T00:00:00Z',startIndex='1'))
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <feed xmlns="http://www.w3.org/2005/Atom" xmlns:xhtml="http://www.w3.org/1999/xhtml" xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/" xmlns:georss="http://www.georss.org/georss" xmlns:gml="http://www.opengis.net/gml" xmlns:time="http://a9.com/-/opensearch/extensions/time/1.0/" xmlns:podaac="http://podaac.jpl.nasa.gov/opensearch/" xmlns:dc="http://purl.org/dc/terms/">
#     <title>PO.DAAC Granule Search Results</title>
#     <updated>2016-07-14T09:40:40.394727Z</updated>
#     <author>
#         <name>PO.DAAC Granule Search Service</name>
#     </author>
#     <id>http://podaac-ts.jpl.nasa.gov/search-3.1.5/granule?datasetId=PODAAC-ASOP2-25X01&amp;bbox=0,0,180,90&amp;startTime=2013-01-01T01%3A30%3A00Z&amp;endTime=2014-01-01T00%3A00%3A00Z&amp;sortBy=timeAsc&amp;format=atom&amp;sessionId=128.149.132.157&amp;itemsPerPage=7</id>
# ...

# %%
# What about Retrieve granule images
#from IPython.display import Image, display
#import cStringIO
from StringIO import StringIO
result = p.load_image_granule(shortName='ASCATB-L2-25km', granuleName='ascat_20121114_035403_metopb_00817_eps_o_250_2101_ovw.l2.nc', request='GetMap', layers='wind_speed_selection', version='1.3.0', format='image/png', srs='', bbox='-180,-66.43,180,79.91', height='300', width='600', service='WMS')
image = result[0].split('/')
imageResult = cStringIO.StringIO(resultTuple[0])
img = Image.open(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-9a58bd0710c7> in <module>()
#       4 resultTuple = p.load_image_granule(shortName='ASCATB-L2-25km', granuleName='ascat_20121114_035403_metopb_00817_eps_o_250_2101_ovw.l2.nc', request='GetMap', layers='wind_speed_selection', version='1.3.0', format='image/png', srs='', bbox='-180,-66.43,180,79.91', height='300', width='600', service='WMS')
#       5 imageResult = cStringIO.StringIO(resultTuple[0])
# ----> 6 img = Image.open(result)
#
# AttributeError: type object 'Image' has no attribute 'open'

# %%
# Finally, lets Exract a granule
result = p.extract_granule(shortName='ASCATA-L2-25km', granuleName='ascat_20130719_230600_metopa_35024_eps_o_250_2200_ovw.l2.nc', bbox='-180,-90,180,90', format='netcdf')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-34-02bc69e95789> in <module>()
#       1 # Finally, lets Exract a granule
# ----> 2 result = p.extract_granule(shortName='ASCATA-L2-25km', granuleName='ascat_20130719_230600_metopa_35024_eps_o_250_2200_ovw.l2.nc', bbox='-180,-90,180,90', format='netcdf')
#
# /usr/local/podaacpy/podaac/podaac.pyc in extract_granule(self, datasetId, shortName, granuleName, bbox, format)
#     452                         granule = urllib.urlretrieve(url,path)
#     453                         if granule[1].getheader('Content-Type') == 'text/plain':
# --> 454                                 raise Exception("Unexpected Error Occured")
#     455
#     456                 except Exception:
#
# Exception: Unexpected Error Occured

# %%
######################################################
# Working with Metadata Compliance Webservices (mcc) #
######################################################

# Compliance Check a Local File
print(m.check_local_file(acdd_version='1.3', gds2_parameters='L4', file_upload='podaac/ascat_20130719_230600_metopa_35024_eps_o_250_2200_ovw.l2.nc', response='json'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-592c4edd8071> in <module>()
#       4
#       5 # Compliance Check a Local File
# ----> 6 print(m.check_local_file('CF', file_upload='podaac/ascat_20130719_230600_metopa_35024_eps_o_250_2200_ovw.l2.nc', response='json'))
#
# TypeError: check_local_file() takes at least 4 arguments (4 given)

# %%
# Compliance Check a Remote File
print(m.check_remote_file(checkers='CF', url_upload='http://test.opendap.org/opendap/data/ncml/agg/dated/CG2006158_120000h_usfc.nc', response='json'))
# Out:
# {
#   "fn": "CG2006158_120000h_usfc.nc",
#   "md5": "80b5cd929a231401fb5ae4958cdb9d55",
#   "model": "NETCDF3_CLASSIC",
#   "results": [
#     {
#       "description": "The conventions define metadata that provide a definitive description of what the data in each variable represents, and the spatial and temporal properties of the data. This enables users of data from different sources to decide which quantities are comparable, and facilitates building applications with powerful extraction, regridding, and display capabilities. The CF conventions generalize and extend the COARDS conventions.",
#       "name": "netCDF Climate and Forecast Metadata Conventions",
#       "passed": 53,
#       "results": [
#         {
#           "name": "Compliance Checker",
#           "passed": 53,
#           "results": [
#             {
#               "hash": -3530678213917924800,
#               "name": "Variable names",
#               "passed": 5,
#               "total": 5
#             },
# ...

# %%
# Thank you for trying out podaacpy
# That concludes the quick start. Hopefully this has been helpful in providing an overview 
# of the main podaacpy features. If you have any issues with this document then please register 
# them at the issue tracker - https://github.com/lewismc/podaacpy/issues
# Please use labels to classify your issue.

# Thanks, 
# Lewis John McGibbney
